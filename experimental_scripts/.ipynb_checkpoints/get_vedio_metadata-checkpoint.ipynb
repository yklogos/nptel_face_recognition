# %%
import pandas as pd

# %%
df = pd.read_csv("../data/csv_files/face_recognition_results_with_diversity.csv")

# %%
df.head()
# Out:
#    Unnamed: 0            vname     nptel_channel_name  \
# 0           0  ZDQBcuVRWYs.mp4  Aerospace Engineering
# 1           1  QLcxx6MJnbA.mp4  Aerospace Engineering
# 2           2  YrkbOeF7wFw.mp4  Aerospace Engineering
# 3           3  _9qwbichO1s.mp4  Aerospace Engineering
# 4           4  BhWzgo7qkbE.mp4  Aerospace Engineering
#
#                       playlistn  \
# 0     Jet and Rocket Propulsion
# 1     Jet and Rocket Propulsion
# 2     Jet and Rocket Propulsion
# 3  Introduction to Aerodynamics
# 4  Introduction to Aerodynamics
#
#                                           vedio_path  \
# 0  /content/drive/My Drive/nptel_face_recognition...
# 1  /content/drive/My Drive/nptel_face_recognition...
# 2  /content/drive/My Drive/nptel_face_recognition...
# 3  /content/drive/My Drive/nptel_face_recognition...
# 4  /content/drive/My Drive/nptel_face_recognition...
#
#                     true_name  accuracy  number of predictions       time  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'vname', 'nptel_channel_name', 'playlistn', 'vedio_path',
#        'true_name', 'accuracy', 'number of predictions', 'time', 'unique',
#        'counts', 'frame_index_list', 'names_list', 'slides_index_list_0.3',
#        'slides_index_list_0.4', 'slides_index_list_0.5',
#        'slides_index_list_0.6', 'slides_index_list_0.7',
#        'slides_index_list_0.8'],
#       dtype='object')

# %%
df[['vname', 'nptel_channel_name', 'playlistn', 'vedio_path']].to_csv("../data/csv_files/vedio_metadata_with_diversity.csv")
