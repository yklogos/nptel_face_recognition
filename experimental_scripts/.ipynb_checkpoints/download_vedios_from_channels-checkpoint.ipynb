# %%
# %%capture
# !pip install pytube3
# Out:
# time: 4.61 s

# %%
# %%capture
# !pip install moviepy
# Out:
# time: 3.97 s

# %%
# play audio in ipython notebook
try:
    import winsound
except ImportError:
    # !pip install winsound
    import winsound
duration = 1000  # milliseconds
freq = 440  # Hz

try:
    # %load_ext autotime
except:
    # !pip install ipython-autotime
    # %load_ext autotime
# Out:
# The autotime extension is already loaded. To reload it, use:
#   %reload_ext autotime
# time: 6.98 ms

# %%
import cv2
import os
import datetime
import math
import matplotlib.pyplot as plt
import requests
import pickle
from lxml import html
import numpy as np
import urllib.request
import face_recognition
import cv2
import matplotlib.pyplot as plt
from pytube import YouTube
from moviepy.video.io.ffmpeg_tools import ffmpeg_extract_subclip
from lxml import html
from googlesearch import search
import pytesseract
import shutil
import youtube_dl
# Out:
# time: 6.98 ms

# %%
def make_dict_from_lists(list1, list2, one2two = True):
    if one2two:
        final = {list1[i]:list2[i] for i in range(len(list1))}
    else:
        final = {list2[i]:list1[i] for i in range(len(list1))}

def make_rgb_bgr(img):
    b,g,r = cv2.split(img)          
    rgb_img = cv2.merge([r,g,b]) 
    return rgb_img

def read_bgr(path):
    return make_rgb_bgr(cv2.imread("sample.jpg", -1))

def imshowg(gray):
    plt.imshow(gray, cmap='gray')
    
def subimg(img, u=0,r=1,d=1,l=0):
    h = img.shape[0]
    b = img.shape[1]
    return img[int(h*u):int(h*d), int(b*l):int(b*r)]

def url_to_image(url):
    try:
        resp = urllib.request.urlopen(url)
        image = np.asarray(bytearray(resp.read()), dtype="uint8")
        image = cv2.imdecode(image, cv2.IMREAD_COLOR)
        return image
    except Exception as e:
        print(e)
        print(url)
        
def save_as_pickle(file_path, file):
    with open(file_path, 'wb') as f:
        pickle.dump(file, f)

def load_from_pickle(file_path):
    with open(file_path, 'rb') as f:
        file = pickle.load(f)
    return file
# Out:
# time: 7.98 ms

# %%
def get_playlists_json_list_from_chanelid(youtube_api_key, channel_id, part = "snippet", maxResults = 3):
    site_url = f"https://www.googleapis.com/youtube/v3/playlists?key={youtube_api_key}&channelId={channel_id}&part={part}&order=date&maxResults={maxResults}"
    r = requests.get(site_url)
    return r.json()

def get_playlists_id_names_list_from_chanelid(youtube_api_key, channel_id, part = "id,snippet", maxResults = 3):
    site_url = f"https://www.googleapis.com/youtube/v3/playlists?key={youtube_api_key}&channelId={channel_id}&part={part}&order=date&maxResults={maxResults}"
    r = requests.get(site_url)
    r_json = r.json()
    playlist_names_list = [w['snippet']['title'] for w in r_json['items']]
    playlistid_list = [w['id'] for w in r_json['items']]
    return playlistid_list, playlist_names_list

def get_vedio_id_list_from_playlistid(youtube_api_key, playlist_id, part = "id,snippet", maxResults = 5):
    site_url = f"https://www.googleapis.com/youtube/v3/playlistItems?key={youtube_api_key}&playlistId={playlist_id}&part={part}&order=date&maxResults={maxResults}"
    r = requests.get(site_url)
    r_json = r.json()
    vedioid_list = [w['snippet']['resourceId']['videoId'] for w in r_json['items']]
    return vedioid_list

# def get_vedioid_list_thumbnail_from_playlistid(youtube_api_key, playlist_id, part = "id,snippet", maxResults = 3):
#     site_url = f"https://www.googleapis.com/youtube/v3/playlistItems?key={youtube_api_key}&playlistId={playlist_id}&part={part}&order=date&maxResults={maxResults}"
#     r = requests.get(site_url)
#     r_json = r.json()
#     vedioid_list = [w['snippet']['resourceId']['videoId'] for w in r_json['items']]
#     thumbnail_url = r_json['items'][0]['snippet']['thumbnails']['maxres']['url']
#     return vedioid_list, thumbnail_url
# Out:
# time: 3.99 ms

# %%
base_dir = "C:\\Users\\YASH\\nptel_face_recognition\data"

youtube_vedio_base_url = "https://www.youtube.com/watch?v="
youtube_api_key = "AIzaSyDvP159lNILjQfqj0CN5f2-srIQ5ZYQBxM"

# all nptel channels
nptel_channel_name_list = ["Aerospace Engineering",
                           "Biotechnology",
                           "Chemical Engineering",
                           "Chemistry and Biochemistry",
                           "Computer Science and Engineering",
                           "Electrical Engineering",
                           "Textile Engineering",
                           "Physics",
                           "Automobile Engineering",
                           "Mathematics",
                            ]

nptel_channel_id_list = ["UCiY8ERfD4qvD_-d-VUWh_GA", 
                         "UCbWTmSK7bYM9kRZAdfy_gyg",
                         "UCqqc1GmsuANsx3s3Y0C-BsQ",
                         "UCE_U8NURXPMGQKwq_J5jfSA",
                         "UCxJp9aEteKmOeobEsHXwxAw",
                         "UCTJn6buigC961hns17ELXAQ",
                         "UC2IIM0OhqB8o8BzDZs-PKqQ",
                         "UC9vycSfjzLCR_w1C59VQo5A",
                         "UCGLlbmSTaLNUPhDwsMe-SgQ",
                         "UCW6912n7NwlBO7rPTIxHm0w"
                        ]

nptel_channel_name_2_id_dict = {n:i for n,i in zip(nptel_channel_name_list, nptel_channel_id_list)}
nptel_channel_id_2_name_dict = {i:n for n,i in zip(nptel_channel_name_list, nptel_channel_id_list)}

pkl_files_dir = os.path.join(base_dir, "pkl_files")
# os.makedirs(pkl_files_dir, exist_ok = True)
# save_as_pickle(os.path.join(pkl_files_dir, "nptel_channel_name_list.pkl"), nptel_channel_name_list)
# save_as_pickle(os.path.join(pkl_files_dir, "nptel_channel_id_list.pkl"), nptel_channel_id_list)
# save_as_pickle(os.path.join(pkl_files_dir, "nptel_channel_name_2_id_dict.pkl"), nptel_channel_name_2_id_dict)
# save_as_pickle(os.path.join(pkl_files_dir, "nptel_channel_id_2_name_dict.pkl"), nptel_channel_id_2_name_dict)

ydl = youtube_dl.YoutubeDL({"outtmpl": "%(id)s.%(ext)s"})
# Out:
# time: 86.8 ms

# %%
# get playlist names, ids and save as pkl from nptel chanel

num_channels = 10
num_playlists = 10
num_vedios = 3

# nptel_channel_name = "Computer Science and Engineering"
for nptel_channel_name in nptel_channel_name_list:
    chanel_pkl_files_dir = os.path.join(pkl_files_dir, nptel_channel_name)
    nptel_channel_id = nptel_channel_name_2_id_dict[nptel_channel_name]
    playlist_id_list, playlist_names_list = get_playlists_id_names_list_from_chanelid(youtube_api_key, nptel_channel_id, 
                                                                                     part = "id,snippet",
                                                                                     maxResults = num_playlists)
    
    os.makedirs(chanel_pkl_files_dir, exist_ok = True)
    save_as_pickle(os.path.join(chanel_pkl_files_dir, "playlist_id_list.pkl"), playlist_id_list)
    save_as_pickle(os.path.join(chanel_pkl_files_dir, "playlist_names_list.pkl"), playlist_names_list)
    
    playlist_name_2_id_dict = {n:i for n,i in zip(playlist_name_list, playlist_id_list)}
    playlist_id_2_name_dict = {i:n for n,i in zip(playlist_name_list, playlist_id_list)}
    save_as_pickle(os.path.join(chanel_pkl_files_dir, "playlist_name_2_id_dict.pkl"), playlist_name_2_id_dict)
    save_as_pickle(os.path.join(chanel_pkl_files_dir, "playlist_id_2_name_dict.pkl"), playlist_id_2_name_dict)
    print(f"saved pkl files for channel: {nptel_channel_name}")
    
    complete_playlist_id_list+= playlist_id_list
    complete_playlist_names_list+= playlist_names_list

complete_playlist_name_2_id_dict = {n:i for n,i in zip(complete_playlist_names_list, complete_playlist_id_list)}
complete_playlist_id_2_name_dict = {n:i for n,i in zip(complete_playlist_names_list, complete_playlist_id_list)}
save_as_pickle(os.path.join(pkl_files_dir, "complete_playlist_name_2_id_dict.pkl"), complete_playlist_name_2_id_dict)
save_as_pickle(os.path.join(pkl_files_dir, "complete_playlist_id_2_name_dict.pkl"), complete_playlist_id_2_name_dict)

winsound.Beep(freq, duration)
# Out:
# saved pkl files for channel: Aerospace Engineering
# saved pkl files for channel: Biotechnology
# saved pkl files for channel: Chemical Engineering
# saved pkl files for channel: Chemistry and Biochemistry
# saved pkl files for channel: Computer Science and Engineering
# saved pkl files for channel: Electrical Engineering
# saved pkl files for channel: Textile Engineering
# saved pkl files for channel: Physics
# saved pkl files for channel: Automobile Engineering
# saved pkl files for channel: Mathematics
# time: 55 s

# %%
# %%capture cap --no-stderr

# get vedio names, ids and save as pkl from playlists

tracebacks_dir = os.path.join(base_dir, "tracebacks")
os.makedirs(tracebacks_dir, exist_ok = True)

play_list_start_idx = 0
num_channels = 5
num_playlists = 5
num_vedios = 2
    
for nptel_channel_name in nptel_channel_name_list:
    print(f'\nfor nptel_channel_name {nptel_channel_name}')
    chanel_pkl_files_dir = os.path.join(pkl_files_dir, nptel_channel_name)
    playlist_id_list = load_from_pickle(os.path.join(chanel_pkl_files_dir, "playlist_id_list.pkl"))
    playlist_names_list = load_from_pickle(os.path.join(chanel_pkl_files_dir, "playlist_names_list.pkl"))
    print(f'number of playlist: {len(playlist_id_list)}')
    
    chanel_vedio_dir = os.path.join(full_vedios_dir, nptel_channel_name)
    s=0
    e=0
    for playlist_id, playlist_name in zip(playlist_id_list[play_list_start_idx:], playlist_names_list[play_list_start_idx:]):
    # for playlist_id, playlist_name in zip([playlist_id_list[0]], [playlist_names_list[0]]):
        playlist_pkl_files_dir = os.path.join(chanel_pkl_files_dir, playlist_name)
        try:
            os.makedirs(playlist_pkl_files_dir, exist_ok = True)
        except Exception as ex:
            print(f"playlist path error: {ex}")
            playlist_id_list.remove(playlist_id)
            playlist_names_list.remove(playlist_name)
            save_as_pickle(os.path.join(chanel_pkl_files_dir, "playlist_id_list.pkl"), playlist_id_list)
            save_as_pickle(os.path.join(chanel_pkl_files_dir, "playlist_names_list.pkl"), playlist_names_list)
            print(f"removed playlist")
            continue
            
        vedio_id_list_path = os.path.join(playlist_pkl_files_dir, 'vedio_id_list.pkl')
        
        if os.path.exists(vedio_id_list_path):
            print(f"{vedio_id_list_path} exists")
            e+=1
        else:
            vedio_id_list = get_vedio_id_list_from_playlistid(youtube_api_key, playlist_id,
                                                             part = "id,snippet", 
                                                             maxResults = num_vedios)
            
            save_as_pickle(os.path.join(playlist_pkl_files_dir, 'vedio_id_list.pkl'), vedio_id_list)
            print(f"{vedio_id_list_path} saved")
            s+=1
        print(f'number of vedios: {len(vedio_id_list)}')
    print(f'for nptel_channel_name {nptel_channel_name} saved: {s}, exists: {e}\n')
# Out:
# time: 12 ms

# %%
with open(os.path.join(tracebacks_dir, "vedio_ids.txt"), 'w', encoding='utf-8') as f:
    f.write(cap.stdout)

# %%
# %%capture cap --no-stderr

# download vedios

full_vedios_dir = os.path.join(base_dir, "full_vedio")
tracebacks_dir = os.path.join(base_dir, "tracebacks")
os.makedirs(tracebacks_dir, exist_ok = True)

# num_channels = 2
# num_playlists = 2
# num_vedios = 2

num_channels = 5
num_playlists = 5
num_vedios = 5
    
# for nptel_channel_name in nptel_channel_name_list:
for nptel_channel_name in nptel_channel_name_list[:num_channels]:
    print(f'\n\n\nfor nptel_channel_name {nptel_channel_name}')
    chanel_pkl_files_dir = os.path.join(pkl_files_dir, nptel_channel_name)
    playlist_id_list = load_from_pickle(os.path.join(chanel_pkl_files_dir, "playlist_id_list.pkl"))[:num_playlists]
    playlist_names_list = load_from_pickle(os.path.join(chanel_pkl_files_dir, "playlist_names_list.pkl"))[:num_playlists]
    print(f'number of playlist: {len(playlist_id_list)}')
    vedio_ext = '.mp4'
    
    cdown=0
    cerr=0
    cexis=0
    chanel_vedio_dir = os.path.join(full_vedios_dir, nptel_channel_name)
    for playlist_id, playlist_name in zip(playlist_id_list, playlist_names_list):
#     for playlist_id, playlist_name in zip(playlist_id_list[play_list_start_idx:], playlist_names_list[play_list_start_idx:]):
#     for playlist_id, playlist_name in zip([playlist_id_list[0]], [playlist_names_list[0]]):
        down=0
        err=0
        exis=0
        print(f'\nfor playlist {playlist_name}')
        playlist_pkl_files_dir = os.path.join(chanel_pkl_files_dir, playlist_name)
        vedio_id_list = load_from_pickle(os.path.join(playlist_pkl_files_dir, 'vedio_id_list.pkl'))[:num_vedios]
        print(f'number of vedios: {len(vedio_id_list)}')
        v_dir = os.path.join(chanel_vedio_dir, playlist_name)
        os.makedirs(v_dir, exist_ok = True)
        for vid in vedio_id_list:
            v_url = youtube_vedio_base_url + vid
            v_fname =  vid + vedio_ext
            v_path = os.path.join(v_dir, v_fname)
            v_name = v_path.split('\\')[-1]

    #         # pytube
    #         try:
    #             j+=1
    #             video = YouTube(v_url)
    #             video.streams.filter(progressive=True).first().download(v_dir)
    #         except Exception as e:
    #             print(f'failed to extract vedio for {v_url} with error {e} using pytube')

            # youtube-dl
            try:
                if not os.path.exists(v_path):
                    ydl.download([v_url])
                    shutil.move(v_fname, v_path)
                    print(f"{v_name} downloaded")
                    down+=1
                else:
                    print(f"{v_name} already downloaded")
                    exis+=1
            except Exception as e:
                print(f'failed to extract vedio for {v_url} with error {e} using youtube-dl')
                err+=1
        cdown+=down
        cerr+=err
        cexis+=exis
        print(f"for playlist {playlist_name}  downloaded: {down}, error: {err}, exists: {exis}")
        
    print(f"\nfor channel {nptel_channel_name}  downloaded: {cdown}, error: {cerr}, exists: {cexis}")
    
winsound.Beep(freq, duration)
# Out:
# for nptel_channel_name Aerospace Engineering
# number of playlist: 5
#
# for playlist Introduction to Aerodynamics
# number of vedios: 5
# _9qwbichO1s.mp4 already downloaded
# [youtube] BhWzgo7qkbE: Downloading webpage
# [download] Destination: BhWzgo7qkbE.mp4
# [download] 100% of 145.40MiB in 00:05
# BhWzgo7qkbE.mp4 downloaded
# [youtube] FKH4DjMdk9I: Downloading webpage
# [download] Destination: FKH4DjMdk9I.mp4
# [download] 100% of 145.69MiB in 00:20
# FKH4DjMdk9I.mp4 downloaded
# [youtube] iliUBZ_Syvg: Downloading webpage
# [youtube] iliUBZ_Syvg: Downloading embed webpage
# ERROR: Unable to extract JS player URL; please report this issue on https://yt-dl.org/bug . Make sure you are using the latest version; see  https://yt-dl.org/update  on how to update. Be sure to call youtube-dl with the --verbose flag and include its complete output.
# failed to extract vedio for https://www.youtube.com/watch?v=iliUBZ_Syvg with error ERROR: Unable to extract JS player URL; please report this issue on https://yt-dl.org/bug . Make sure you are using the latest version; see  https://yt-dl.org/update  on how to update. Be sure to call youtube-dl with the --verbose flag and include its complete output. using youtube-dl
# [youtube] VhybIE82B6M: Downloading webpage
# [download] Destination: VhybIE82B6M.mp4
# [download] 100% of 152.63MiB in 00:50
# VhybIE82B6M.mp4 downloaded
# for playlist Introduction to Aerodynamics  downloaded: 3, error: 1, exists: 1
#
# for playlist Turbomachinery Aerodynamics
# number of vedios: 5
# dafjkTM2nlg.mp4 already downloaded
# VCWzszufr7I.mp4 already downloaded
# [youtube] U6ipqqt6Spc: Downloading webpage
# [download] Destination: U6ipqqt6Spc.mp4
# [download] 100% of 127.66MiB in 00:06
# U6ipqqt6Spc.mp4 downloaded
# [youtube] 2K0EJaimBas: Downloading webpage
# [download] Destination: 2K0EJaimBas.mp4
# [download] 100% of 132.80MiB in 00:41
# 2K0EJaimBas.mp4 downloaded
# [youtube] utL9RWUdVVs: Downloading webpage
# [download] Destination: utL9RWUdVVs.mp4
# [download] 100% of 134.91MiB in 01:09
# utL9RWUdVVs.mp4 downloaded
# for playlist Turbomachinery Aerodynamics  downloaded: 3, error: 0, exists: 2
#
# for playlist Jet and Rocket Propulsion
# number of vedios: 5
# QLcxx6MJnbA.mp4 already downloaded
# YrkbOeF7wFw.mp4 already downloaded
# [youtube] bcBrCQGI1tY: Downloading webpage
# [download] Destination: bcBrCQGI1tY.mp4
# [download] 100% of 121.53MiB in 00:07
# bcBrCQGI1tY.mp4 downloaded
# [youtube] UcDNM18TkiU: Downloading webpage
# [download] Destination: UcDNM18TkiU.mp4
# [download] 100% of 119.83MiB in 00:05
# UcDNM18TkiU.mp4 downloaded
# [youtube] ZDQBcuVRWYs: Downloading webpage
# [download] Destination: ZDQBcuVRWYs.mp4
# [download] 100% of 124.60MiB in 00:05
# ZDQBcuVRWYs.mp4 downloaded
# for playlist Jet and Rocket Propulsion  downloaded: 3, error: 0, exists: 2
#
# for playlist Foundation of Scientific Computing
# number of vedios: 5
# MkiUBJcgdUY.mp4 already downloaded
# vT40FWuvIB8.mp4 already downloaded
# [youtube] s5cccilePqg: Downloading webpage
# [download] Destination: s5cccilePqg.mp4
# [download] 100% of 141.11MiB in 00:39
# s5cccilePqg.mp4 downloaded
# [youtube] hkBQutyQla8: Downloading webpage
# [download] Destination: hkBQutyQla8.mp4
# [download] 100% of 150.43MiB in 00:25
# hkBQutyQla8.mp4 downloaded
# [youtube] vHz-8-bSj00: Downloading webpage
# [youtube] vHz-8-bSj00: Downloading MPD manifest
# [download] Destination: vHz-8-bSj00.mp4
# [download] 100% of 200.11MiB in 01:40
# vHz-8-bSj00.mp4 downloaded
# for playlist Foundation of Scientific Computing  downloaded: 3, error: 0, exists: 2
#
# for playlist Instability and Transition of Fluid Flows
# number of vedios: 5
# 2hfaiu6x0ow.mp4 already downloaded
# z77l0_F6qyY.mp4 already downloaded
# [youtube] paHi-4caiSk: Downloading webpage
# [download] Destination: paHi-4caiSk.mp4
# [download] 100% of 139.87MiB in 00:14
# paHi-4caiSk.mp4 downloaded
# [youtube] GY0GnH2gEnM: Downloading webpage
# [download] Destination: GY0GnH2gEnM.mp4
# [download] 100% of 144.75MiB in 00:17
# GY0GnH2gEnM.mp4 downloaded
# [youtube] wxt-xeKy0lA: Downloading webpage
# [youtube] wxt-xeKy0lA: Downloading MPD manifest
# [download] Destination: wxt-xeKy0lA.mp4
# [download] 100% of 149.00MiB in 01:13
# wxt-xeKy0lA.mp4 downloaded
# for playlist Instability and Transition of Fluid Flows  downloaded: 3, error: 0, exists: 2
#
# for channel Aerospace Engineering  downloaded: 15, error: 1, exists: 9
#
#
#
# for nptel_channel_name Biotechnology
# number of playlist: 5
#
# for playlist Introduction To Proteomics
# number of vedios: 5
# oIWhVNK-Re8.mp4 already downloaded
# Y_KFAq4UpHM.mp4 already downloaded
# [youtube] SQISTJMZeVY: Downloading webpage
# [youtube] SQISTJMZeVY: Downloading MPD manifest
# [download] Destination: SQISTJMZeVY.mp4
# [download] 100% of 69.78MiB in 00:05
# SQISTJMZeVY.mp4 downloaded
# [youtube] gtgq71YfeU4: Downloading webpage
# [youtube] gtgq71YfeU4: Downloading MPD manifest
# [download] Destination: gtgq71YfeU4.mp4
# [download] 100% of 67.90MiB in 00:04
# gtgq71YfeU4.mp4 downloaded
# [youtube] eiv9MNCrV4Q: Downloading webpage
# [youtube] eiv9MNCrV4Q: Downloading MPD manifest
# [download] Destination: eiv9MNCrV4Q.mp4
# [download] 100% of 57.58MiB in 00:10
# eiv9MNCrV4Q.mp4 downloaded
# for playlist Introduction To Proteomics  downloaded: 3, error: 0, exists: 2
#
# for playlist Introduction to Mechanobiology
# number of vedios: 5
# Vnxy8BcCTUc.mp4 already downloaded
# orfE5Q33yto.mp4 already downloaded
# [youtube] IgqfvQkKc_E: Downloading webpage
# [youtube] IgqfvQkKc_E: Downloading MPD manifest
# [download] Destination: IgqfvQkKc_E.mp4
# [download] 100% of 116.70MiB in 00:39
# IgqfvQkKc_E.mp4 downloaded
# [youtube] Bu07aFJGeyw: Downloading webpage
# [youtube] Bu07aFJGeyw: Downloading MPD manifest
# [download] Destination: Bu07aFJGeyw.mp4
# [download] 100% of 141.84MiB in 00:31
# Bu07aFJGeyw.mp4 downloaded
# [youtube] SbFKcg1JJ-c: Downloading webpage
# [youtube] SbFKcg1JJ-c: Downloading MPD manifest
# [download] Destination: SbFKcg1JJ-c.mp4
# [download] 100% of 176.22MiB in 01:02
# SbFKcg1JJ-c.mp4 downloaded
# for playlist Introduction to Mechanobiology  downloaded: 3, error: 0, exists: 2
#
# for playlist Industrial Biotechnology
# number of vedios: 5
# 2CqjfuTu4K0.mp4 already downloaded
# K2HfqV3sAx0.mp4 already downloaded
# [youtube] ZgM3h0xTUfM: Downloading webpage
# [youtube] ZgM3h0xTUfM: Downloading MPD manifest
# [download] Destination: ZgM3h0xTUfM.mp4
# [download] 100% of 52.55MiB in 00:25
# ZgM3h0xTUfM.mp4 downloaded
# [youtube] LwIe275w1Jc: Downloading webpage
# [youtube] LwIe275w1Jc: Downloading embed webpage
# ERROR: Unable to extract JS player URL; please report this issue on https://yt-dl.org/bug . Make sure you are using the latest version; see  https://yt-dl.org/update  on how to update. Be sure to call youtube-dl with the --verbose flag and include its complete output.
# failed to extract vedio for https://www.youtube.com/watch?v=LwIe275w1Jc with error ERROR: Unable to extract JS player URL; please report this issue on https://yt-dl.org/bug . Make sure you are using the latest version; see  https://yt-dl.org/update  on how to update. Be sure to call youtube-dl with the --verbose flag and include its complete output. using youtube-dl
# [youtube] eRigIJ3aP-M: Downloading webpage
# [youtube] eRigIJ3aP-M: Downloading MPD manifest
# [download] Destination: eRigIJ3aP-M.mp4
# [download] 100% of 57.74MiB in 00:10
# eRigIJ3aP-M.mp4 downloaded
# for playlist Industrial Biotechnology  downloaded: 2, error: 1, exists: 2
#
# for playlist Biomedical nanotechnology
# number of vedios: 5
# k61wjab7iUs.mp4 already downloaded
# AEWqAcSeQm4.mp4 already downloaded
# [youtube] Z51R49OOqAA: Downloading webpage
# [download] Destination: Z51R49OOqAA.mp4
# [download] 100% of 151.15MiB in 00:10
# Z51R49OOqAA.mp4 downloaded
# [youtube] 0md5JdAbj4U: Downloading webpage
# [download] Destination: 0md5JdAbj4U.mp4
# [download] 100% of 175.01MiB in 00:24
# 0md5JdAbj4U.mp4 downloaded
# [youtube] lFYs3XDu4fQ: Downloading webpage
# [download] Destination: lFYs3XDu4fQ.mp4
# [download] 100% of 131.55MiB in 00:19
# lFYs3XDu4fQ.mp4 downloaded
# for playlist Biomedical nanotechnology  downloaded: 3, error: 0, exists: 2
#
# for playlist Bio electricity
# number of vedios: 5
# FXPDVHl4Hl4.mp4 already downloaded
# QiwxdcckPGc.mp4 already downloaded
# [youtube] 0q5zeAWXPXY: Downloading webpage
# ERROR: unable to download video data: <urlopen error [Errno 11001] getaddrinfo failed>
# failed to extract vedio for https://www.youtube.com/watch?v=0q5zeAWXPXY with error ERROR: unable to download video data: <urlopen error [Errno 11001] getaddrinfo failed> using youtube-dl
# [youtube] cuiVnm6YBLk: Downloading webpage
# [download] Destination: cuiVnm6YBLk.mp4
# [download] 100% of 123.99MiB in 00:36
# cuiVnm6YBLk.mp4 downloaded
# [youtube] SHFf3cYaj0k: Downloading webpage
# [download] Destination: SHFf3cYaj0k.mp4
# [download] 100% of 81.92MiB in 00:27
# SHFf3cYaj0k.mp4 downloaded
# for playlist Bio electricity  downloaded: 2, error: 1, exists: 2
#
# for channel Biotechnology  downloaded: 13, error: 2, exists: 10
#
#
#
# for nptel_channel_name Chemical Engineering
# number of playlist: 5
#
# for playlist Phase Equilibrium Thermodynamics
# number of vedios: 5
# [youtube] Lz0xqu3HvD0: Downloading webpage
# [youtube] Lz0xqu3HvD0: Downloading embed webpage
# ERROR: Unable to extract JS player URL; please report this issue on https://yt-dl.org/bug . Make sure you are using the latest version; see  https://yt-dl.org/update  on how to update. Be sure to call youtube-dl with the --verbose flag and include its complete output.
# failed to extract vedio for https://www.youtube.com/watch?v=Lz0xqu3HvD0 with error ERROR: Unable to extract JS player URL; please report this issue on https://yt-dl.org/bug . Make sure you are using the latest version; see  https://yt-dl.org/update  on how to update. Be sure to call youtube-dl with the --verbose flag and include its complete output. using youtube-dl
# LkXOVHTkWXQ.mp4 already downloaded
# [youtube] N3fWRvIu8RM: Downloading webpage
# [youtube] N3fWRvIu8RM: Downloading MPD manifest
# [download] Destination: N3fWRvIu8RM.mp4
# [download] 100% of 79.67MiB in 00:23
# N3fWRvIu8RM.mp4 downloaded
# [youtube] RxndX16xtfk: Downloading webpage
# [youtube] RxndX16xtfk: Downloading embed webpage
# ERROR: Unable to extract JS player URL; please report this issue on https://yt-dl.org/bug . Make sure you are using the latest version; see  https://yt-dl.org/update  on how to update. Be sure to call youtube-dl with the --verbose flag and include its complete output.
# failed to extract vedio for https://www.youtube.com/watch?v=RxndX16xtfk with error ERROR: Unable to extract JS player URL; please report this issue on https://yt-dl.org/bug . Make sure you are using the latest version; see  https://yt-dl.org/update  on how to update. Be sure to call youtube-dl with the --verbose flag and include its complete output. using youtube-dl
# [youtube] L68486TLouE: Downloading webpage
# [youtube] L68486TLouE: Downloading MPD manifest
# [download] Destination: L68486TLouE.mp4
# [download] 100% of 72.04MiB in 00:22
# L68486TLouE.mp4 downloaded
# for playlist Phase Equilibrium Thermodynamics  downloaded: 2, error: 2, exists: 1
#
# for playlist Advanced Mathematical Techniques in Chemical Engineering
# number of vedios: 5
# z5tNwyS_eys.mp4 already downloaded
# a16YzM1Q-5Y.mp4 already downloaded
# [youtube] UbOnRXAEz3Y: Downloading webpage
# [download] Destination: UbOnRXAEz3Y.mp4
# [download] 100% of 148.24MiB in 00:21
# UbOnRXAEz3Y.mp4 downloaded
# [youtube] YnVEqTnopuc: Downloading webpage
# [download] Destination: YnVEqTnopuc.mp4
# [download] 100% of 136.05MiB in 01:07
# YnVEqTnopuc.mp4 downloaded
# [youtube] NLxaZGMt-8M: Downloading webpage
# [download] Destination: NLxaZGMt-8M.mp4
# [download] 100% of 139.24MiB in 00:28
# NLxaZGMt-8M.mp4 downloaded
# for playlist Advanced Mathematical Techniques in Chemical Engineering  downloaded: 3, error: 0, exists: 2
#
# for playlist Particle Characterization (PG)
# number of vedios: 5
# -QQm3rFIEWA.mp4 already downloaded
# ZVlG7GSiWuc.mp4 already downloaded
# [youtube] -0kKPEGbyx0: Downloading webpage
# [download] Destination: -0kKPEGbyx0.mp4
# [download] 100% of 125.75MiB in 00:20
# -0kKPEGbyx0.mp4 downloaded
# [youtube] jNo-mzKZRxk: Downloading webpage
# [download] Destination: jNo-mzKZRxk.mp4
# [download] 100% of 131.03MiB in 00:20
# jNo-mzKZRxk.mp4 downloaded
# [youtube] pa-TK8TQHQ4: Downloading webpage
# [youtube] pa-TK8TQHQ4: Downloading MPD manifest
# [download] Destination: pa-TK8TQHQ4.mp4
# [download] 100% of 131.81MiB in 00:21
# pa-TK8TQHQ4.mp4 downloaded
# for playlist Particle Characterization (PG)  downloaded: 3, error: 0, exists: 2
#
# for playlist Mass Transfer Operations I
# number of vedios: 5
# EyREi7l5020.mp4 already downloaded
# pMDs_J_zAeA.mp4 already downloaded
# [youtube] HiMOMeAxOXo: Downloading webpage
# [download] Destination: HiMOMeAxOXo.mp4
# [download] 100% of 61.52MiB in 00:27
# HiMOMeAxOXo.mp4 downloaded
# [youtube] l2Q4WF3ljIk: Downloading webpage
# [download] Destination: l2Q4WF3ljIk.mp4
# [download] 100% of 59.67MiB in 00:15
# l2Q4WF3ljIk.mp4 downloaded
# [youtube] b-lAePuQ-z0: Downloading webpage
# [download] Destination: b-lAePuQ-z0.mp4
# [download] 100% of 73.92MiB in 00:23
# b-lAePuQ-z0.mp4 downloaded
# for playlist Mass Transfer Operations I  downloaded: 3, error: 0, exists: 2
#
# for playlist Microscale Transport Processes
# number of vedios: 5
# kF6zAl5mV8Q.mp4 already downloaded
# kXK7_OKlu38.mp4 already downloaded
# [youtube] 0QoUcutTU-o: Downloading webpage
# [download] Destination: 0QoUcutTU-o.mp4
# [download] 100% of 136.22MiB in 00:46
# 0QoUcutTU-o.mp4 downloaded
# [youtube] 6pl4bOPh-MM: Downloading webpage
# [youtube] 6pl4bOPh-MM: Downloading MPD manifest
# [download] Destination: 6pl4bOPh-MM.mp4
# [download] 100% of 132.64MiB in 00:46
# 6pl4bOPh-MM.mp4 downloaded
# [youtube] CF23DwmH5Z8: Downloading webpage
# [youtube] CF23DwmH5Z8: Downloading MPD manifest
# [download] Destination: CF23DwmH5Z8.mp4
# [download] 100% of 123.08MiB in 00:20
# CF23DwmH5Z8.mp4 downloaded
# for playlist Microscale Transport Processes  downloaded: 3, error: 0, exists: 2
#
# for channel Chemical Engineering  downloaded: 14, error: 2, exists: 9
#
#
#
# for nptel_channel_name Chemistry and Biochemistry
# number of playlist: 5
#
# for playlist Analytical Chemistry
# number of vedios: 5
# KHpRNb_38OM.mp4 already downloaded
# qJ8cjdCCd_Q.mp4 already downloaded
# [youtube] wrnXdihS4K8: Downloading webpage
# [download] Destination: wrnXdihS4K8.mp4
# [download] 100% of 62.95MiB in 00:13
# wrnXdihS4K8.mp4 downloaded
# [youtube] JJV0xFetJxg: Downloading webpage
# [download] Destination: JJV0xFetJxg.mp4
# [download] 100% of 48.88MiB in 00:25
# JJV0xFetJxg.mp4 downloaded
# [youtube] gI8CA0gZpVg: Downloading webpage
# [youtube] gI8CA0gZpVg: Downloading MPD manifest
# [download] Destination: gI8CA0gZpVg.mp4
# [download] 100% of 85.28MiB in 00:13
# gI8CA0gZpVg.mp4 downloaded
# for playlist Analytical Chemistry  downloaded: 3, error: 0, exists: 2
#
# for playlist Stereochemistry
# number of vedios: 5
# T6xDcGWOEro.mp4 already downloaded
# hH2Zfucp0oo.mp4 already downloaded
# [youtube] gTMDbc2N2fw: Downloading webpage
# [youtube] gTMDbc2N2fw: Downloading embed webpage
# ERROR: Unable to extract JS player URL; please report this issue on https://yt-dl.org/bug . Make sure you are using the latest version; see  https://yt-dl.org/update  on how to update. Be sure to call youtube-dl with the --verbose flag and include its complete output.
# failed to extract vedio for https://www.youtube.com/watch?v=gTMDbc2N2fw with error ERROR: Unable to extract JS player URL; please report this issue on https://yt-dl.org/bug . Make sure you are using the latest version; see  https://yt-dl.org/update  on how to update. Be sure to call youtube-dl with the --verbose flag and include its complete output. using youtube-dl
# [youtube] u9-3Gegn8kk: Downloading webpage
# [youtube] u9-3Gegn8kk: Downloading embed webpage
# ERROR: Unable to extract JS player URL; please report this issue on https://yt-dl.org/bug . Make sure you are using the latest version; see  https://yt-dl.org/update  on how to update. Be sure to call youtube-dl with the --verbose flag and include its complete output.
# failed to extract vedio for https://www.youtube.com/watch?v=u9-3Gegn8kk with error ERROR: Unable to extract JS player URL; please report this issue on https://yt-dl.org/bug . Make sure you are using the latest version; see  https://yt-dl.org/update  on how to update. Be sure to call youtube-dl with the --verbose flag and include its complete output. using youtube-dl
# [youtube] ekiEA_i5AVc: Downloading webpage
# [youtube] ekiEA_i5AVc: Downloading MPD manifest
# [download] Destination: ekiEA_i5AVc.mp4
# [download] 100% of 52.81MiB in 00:03
# ekiEA_i5AVc.mp4 downloaded
# for playlist Stereochemistry  downloaded: 1, error: 2, exists: 2
#
# for playlist Advance Analytical Course
# number of vedios: 5
# E1Woj_Mz7fc.mp4 already downloaded
# EcFIi2Vp-Bk.mp4 already downloaded
# [youtube] EBqBgh4zQlc: Downloading webpage
# [download] Destination: EBqBgh4zQlc.mp4
# [download] 100% of 107.16MiB in 00:19
# EBqBgh4zQlc.mp4 downloaded
# [youtube] FgtpAWCiMXU: Downloading webpage
# [download] Destination: FgtpAWCiMXU.mp4
# [download] 100% of 110.97MiB in 00:19
# FgtpAWCiMXU.mp4 downloaded
# [youtube] WP_os9-sKBA: Downloading webpage
# [download] Destination: WP_os9-sKBA.mp4
# [download] 100% of 106.10MiB in 00:52
# WP_os9-sKBA.mp4 downloaded
# for playlist Advance Analytical Course  downloaded: 3, error: 0, exists: 2
#
# for playlist BioChemistry I
# number of vedios: 5
# DhwAp6yQHQI.mp4 already downloaded
# Wj2g9Cf_IDc.mp4 already downloaded
# [youtube] YWEiQlEUFak: Downloading webpage
# [download] Destination: YWEiQlEUFak.mp4
# [download] 100% of 122.61MiB in 00:17
# YWEiQlEUFak.mp4 downloaded
# [youtube] Fp1wKo72b2A: Downloading webpage
# [download] Destination: Fp1wKo72b2A.mp4
# [download] 100% of 88.62MiB in 00:04
# Fp1wKo72b2A.mp4 downloaded
# [youtube] CyYaX0vFdhI: Downloading webpage
# [download] Destination: CyYaX0vFdhI.mp4
# [download] 100% of 86.01MiB in 00:04
# CyYaX0vFdhI.mp4 downloaded
# for playlist BioChemistry I  downloaded: 3, error: 0, exists: 2
#
# for playlist Introduction to Organometallic Chemistry
# number of vedios: 5
# 8pqCeN7GoMc.mp4 already downloaded
# etxRR08x7x8.mp4 already downloaded
# [youtube] EL7bSAKCRwE: Downloading webpage
# [download] Destination: EL7bSAKCRwE.mp4
# [download] 100% of 108.70MiB in 00:37
# EL7bSAKCRwE.mp4 downloaded
# [youtube] nadRJbFKaug: Downloading webpage
# [download] Destination: nadRJbFKaug.mp4
# [download] 100% of 106.34MiB in 00:06
# nadRJbFKaug.mp4 downloaded
# [youtube] xdaCCHxEpTk: Downloading webpage
# [download] Destination: xdaCCHxEpTk.mp4
# [download] 100% of 89.52MiB in 00:32
# xdaCCHxEpTk.mp4 downloaded
# for playlist Introduction to Organometallic Chemistry  downloaded: 3, error: 0, exists: 2
#
# for channel Chemistry and Biochemistry  downloaded: 13, error: 2, exists: 10
#
#
#
# for nptel_channel_name Computer Science and Engineering
# number of playlist: 5
#
# for playlist Introduction to parallel Programming in Open MP
# number of vedios: 5
# a8R784VtXBg.mp4 already downloaded
# UrjytgchRWM.mp4 already downloaded
# [youtube] FlML_53r-zw: Downloading webpage
# [youtube] FlML_53r-zw: Downloading MPD manifest
# [download] Destination: FlML_53r-zw.mp4
# [download] 100% of 14.57MiB in 00:02
# FlML_53r-zw.mp4 downloaded
# [youtube] uIQOc32NivI: Downloading webpage
# [download] Destination: uIQOc32NivI.mp4
# [download] 100% of 27.22MiB in 00:06
# uIQOc32NivI.mp4 downloaded
# [youtube] fUS5dCzdSrQ: Downloading webpage
# [youtube] fUS5dCzdSrQ: Downloading MPD manifest
# [download] Destination: fUS5dCzdSrQ.mp4
# [download] 100% of 11.82MiB in 00:04
# fUS5dCzdSrQ.mp4 downloaded
# for playlist Introduction to parallel Programming in Open MP  downloaded: 3, error: 0, exists: 2
#
# for playlist Introduction to R Software
# number of vedios: 5
# N-DQ8iDlH_U.mp4 already downloaded
# A_I5XAtkxiY.mp4 already downloaded
# [youtube] ueFXTnG8ZC0: Downloading webpage
# [download] Destination: ueFXTnG8ZC0.mp4
# [download] 100% of 78.07MiB in 00:11
# ueFXTnG8ZC0.mp4 downloaded
# [youtube] 668keuD73k4: Downloading webpage
# [download] Destination: 668keuD73k4.mp4
# [download] 100% of 103.89MiB in 00:07
# 668keuD73k4.mp4 downloaded
# [youtube] SJpd7KC18fQ: Downloading webpage
# [download] Destination: SJpd7KC18fQ.mp4
# [download] 100% of 79.05MiB in 00:05
# SJpd7KC18fQ.mp4 downloaded
# for playlist Introduction to R Software  downloaded: 3, error: 0, exists: 2
#
# for playlist Artificial Intelligence Search Methods for problem Solving
# number of vedios: 5
# AETGmGYy0UU.mp4 already downloaded
# cckckL3uOW8.mp4 already downloaded
# [youtube] _MhgsoPHvYo: Downloading webpage
# [download] Destination: _MhgsoPHvYo.mp4
# [download] 100% of 74.62MiB in 00:17
# _MhgsoPHvYo.mp4 downloaded
# [youtube] X9PhasOXlT8: Downloading webpage
# [download] Destination: X9PhasOXlT8.mp4
# [download] 100% of 73.38MiB in 00:22
# X9PhasOXlT8.mp4 downloaded
# [youtube] ws89tmbpt8w: Downloading webpage
# [download] Destination: ws89tmbpt8w.mp4
# [download] 100% of 58.12MiB in 00:19
# ws89tmbpt8w.mp4 downloaded
# for playlist Artificial Intelligence Search Methods for problem Solving  downloaded: 3, error: 0, exists: 2
#
# for playlist Hardware Modeling using Verilog
# number of vedios: 5
# [youtube] NCrlyaXMAn8: Downloading webpage
# [youtube] NCrlyaXMAn8: Downloading embed webpage
# ERROR: Unable to extract JS player URL; please report this issue on https://yt-dl.org/bug . Make sure you are using the latest version; see  https://yt-dl.org/update  on how to update. Be sure to call youtube-dl with the --verbose flag and include its complete output.
# failed to extract vedio for https://www.youtube.com/watch?v=NCrlyaXMAn8 with error ERROR: Unable to extract JS player URL; please report this issue on https://yt-dl.org/bug . Make sure you are using the latest version; see  https://yt-dl.org/update  on how to update. Be sure to call youtube-dl with the --verbose flag and include its complete output. using youtube-dl
# [youtube] NdWTDZ7dg-8: Downloading webpage
# [youtube] NdWTDZ7dg-8: Downloading embed webpage
# ERROR: Unable to extract JS player URL; please report this issue on https://yt-dl.org/bug . Make sure you are using the latest version; see  https://yt-dl.org/update  on how to update. Be sure to call youtube-dl with the --verbose flag and include its complete output.
# failed to extract vedio for https://www.youtube.com/watch?v=NdWTDZ7dg-8 with error ERROR: Unable to extract JS player URL; please report this issue on https://yt-dl.org/bug . Make sure you are using the latest version; see  https://yt-dl.org/update  on how to update. Be sure to call youtube-dl with the --verbose flag and include its complete output. using youtube-dl
# [youtube] 9uw25PU5B3k: Downloading webpage
# [download] Destination: 9uw25PU5B3k.mp4
# [download] 100% of 80.08MiB in 00:14
# 9uw25PU5B3k.mp4 downloaded
# [youtube] hENRfpN80SM: Downloading webpage
# [youtube] hENRfpN80SM: Downloading MPD manifest
# [download] Destination: hENRfpN80SM.mp4
# [download] 100% of 43.14MiB in 00:02
# hENRfpN80SM.mp4 downloaded
# [youtube] 6r4ja44Bq1k: Downloading webpage
# [download] Destination: 6r4ja44Bq1k.mp4
# [download] 100% of 57.66MiB in 00:02
# 6r4ja44Bq1k.mp4 downloaded
# for playlist Hardware Modeling using Verilog  downloaded: 3, error: 2, exists: 0
#
# for playlist Cloud Computing
# number of vedios: 5
# NzZXz3fJf6o.mp4 already downloaded
# SqG-b5E9vHs.mp4 already downloaded
# [youtube] lOh2x-UACaU: Downloading webpage
# [youtube] lOh2x-UACaU: Downloading embed webpage
# ERROR: Unable to extract JS player URL; please report this issue on https://yt-dl.org/bug . Make sure you are using the latest version; see  https://yt-dl.org/update  on how to update. Be sure to call youtube-dl with the --verbose flag and include its complete output.
# failed to extract vedio for https://www.youtube.com/watch?v=lOh2x-UACaU with error ERROR: Unable to extract JS player URL; please report this issue on https://yt-dl.org/bug . Make sure you are using the latest version; see  https://yt-dl.org/update  on how to update. Be sure to call youtube-dl with the --verbose flag and include its complete output. using youtube-dl
# [youtube] fZ3D6HQrWzs: Downloading webpage
# [download] Destination: fZ3D6HQrWzs.mp4
# [download] 100% of 70.38MiB in 00:02
# fZ3D6HQrWzs.mp4 downloaded
# [youtube] 57X6frOmwn0: Downloading webpage
# [youtube] 57X6frOmwn0: Downloading embed webpage
# ERROR: Unable to extract JS player URL; please report this issue on https://yt-dl.org/bug . Make sure you are using the latest version; see  https://yt-dl.org/update  on how to update. Be sure to call youtube-dl with the --verbose flag and include its complete output.
# failed to extract vedio for https://www.youtube.com/watch?v=57X6frOmwn0 with error ERROR: Unable to extract JS player URL; please report this issue on https://yt-dl.org/bug . Make sure you are using the latest version; see  https://yt-dl.org/update  on how to update. Be sure to call youtube-dl with the --verbose flag and include its complete output. using youtube-dl
# for playlist Cloud Computing  downloaded: 1, error: 2, exists: 2
#
# for channel Computer Science and Engineering  downloaded: 13, error: 4, exists: 8
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-22af6b35734e> in <module>
#      76 with open(os.path.join(tracebacks_dir, "downloading_vedios.txt"), 'w', encoding='utf-8') as f:
#      77 # with open("vedio_ids.txt", 'w', encoding='utf-8') as f:
# ---> 78     f.write(cap.stdout)
#      79
#      80 winsound.Beep(freq, duration)
#
# NameError: name 'cap' is not defined
# time: 27min 35s

# %%
# with open(os.path.join(tracebacks_dir, "downloading_vedios.txt"), 'w', encoding='utf-8') as f:
#     f.write(cap.stdout)
